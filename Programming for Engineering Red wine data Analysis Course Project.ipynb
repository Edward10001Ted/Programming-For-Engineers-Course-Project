# %% [markdown]
# <h1>Index Number: 11356824</h1>
# <h1>Name: Edward Opoku Agyemang</h1>
# <h1>Class: CPEN L200</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset = pd.read_csv('red_wine.csv')

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
dataset.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %%
dataset.isnull().sum()
# Out:
# fixed acidity           1
# volatile acidity        1
# citric acid             0
# residual sugar          0
# chlorides               4
# free sulfur dioxide     1
# total sulfur dioxide    0
# density                 1
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %%
#I'm going to clean the data by removing all null values
dataset = dataset.dropna()

# %% [markdown]
# <p>As we can see there are some null values in the dataset and therefore we have to remove them</p>

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1590 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1590 non-null   float64
#  1   volatile acidity      1590 non-null   float64
#  2   citric acid           1590 non-null   float64
#  3   residual sugar        1590 non-null   float64
#  4   chlorides             1590 non-null   float64
#  5   free sulfur dioxide   1590 non-null   float64
#  6   total sulfur dioxide  1590 non-null   float64
#  7   density               1590 non-null   float64
#  8   pH                    1590 non-null   float64
#  9   sulphates             1590 non-null   float64
#  10  alcohol               1590 non-null   float64
#  11  quality               1590 non-null   float64
# dtypes: float64(12)
# memory usage: 161.5 KB

# %%
dataset.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# <p title="no null" style="color:green">All the null values have been removed</p>

# %%
#Now let's check the correlation of the columns amongst themselves
corr = dataset.corr()
corr
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.254341     0.671312
# volatile acidity          -0.254341          1.000000    -0.551409
# citric acid                0.671312         -0.551409     1.000000
# residual sugar             0.115045          0.001421     0.144175
# chlorides                  0.093711          0.060803     0.205018
# free sulfur dioxide       -0.155482         -0.011571    -0.061793
# total sulfur dioxide      -0.113596          0.074772     0.036837
# density                    0.667684          0.023179     0.363958
# pH                        -0.683890          0.235076    -0.544230
# sulphates                  0.181817         -0.261613     0.313335
# alcohol                   -0.060368         -0.203852     0.111092
# quality                    0.124716         -0.391009     0.227406
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
import statsmodels.api as sm

# %%
sm.graphics.plot_corr(corr,xnames=corr.columns)

# %%
import seaborn as sns

# %%
#similar to the infomation the previous diagram gave but in scatter plot form
sns.pairplot(dataset)

# %%
features = list(dataset.columns)

# %%
features
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %% [markdown]
# <h1>A Report on The Graphs And Plots</h1>
# <p> This read wine has 12 features and the are as follows:'fixed acidity','volatile acidity','citric acid','residual sugar', 'chlorides',
# 'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol','quality'
# </p>
# <p>The plots show the relationship between these features</p>
# <p>The read colors in the correlation matrix show that the features highly correlate and then blue colors show that they weakly,don't or negatively correlate</p>
# <p>The pairplot "scatter plot" shows the same thing using a scatter plot instead of the color map the previous diagram used</p>
# <p>With these diagrams we can draw all insights concerning the relationships between the features of the red wine dataset</p>
# <p>From the color map one can see that fixed acid and citric acid highly correlate as show with the orange color and from the pairplot it can be seen that they highly correlate by positive corrlation of the scatter diagram</p>
# <p>Using the technique mentioned above one can see that fixed acid and pH negatively correlate strongly</p>
